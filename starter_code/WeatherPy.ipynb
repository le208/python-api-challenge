# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API call
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"


# List of City Data
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print ("-" * 15)


# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in list
for index, city in enumerate(cities):
    # Group cities in sets of 50 for loggin purpose
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    
    # Log the URL and set number
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Extract out max temp humidity and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the city info into the city data list
        city_data.append({
            "City" :city,
            "Lat" :city_lat,
            "Lng" :city_lng,
            "Max Temp" :city_max_temp,
            "Humidity" :city_humidity,
            "Cloudiness" :city_clouds,
            "Windspeed" :city_wind,
            "Country" :city_country,
            "Date" :city_date  
        })
    except:
        print("City not found. Skipping ...")
        pass
    # Indicate that data loading is complete
        print("-----------------------")
        print("Data Retrieval Complete")
        print("-----------------------")
# Out:
# Beginning Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | mogadishu
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | arraial do cabo
# Processing Record 12 of Set 1 | dehloran
# Processing Record 13 of Set 1 | sukhobezvodnoye
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | kodinsk
# Processing Record 21 of Set 1 | batagay
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | puerto lopez
# Processing Record 26 of Set 1 | mayo
# Processing Record 27 of Set 1 | talnakh
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | brasileia
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | vardo
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | tarata
# Processing Record 35 of Set 1 | vostok
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | san isidro
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | bilma
# Processing Record 43 of Set 1 | dawei
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 45 of Set 1 | lulea
# Processing Record 46 of Set 1 | olafsvik
# Processing Record 47 of Set 1 | kieta
# Processing Record 48 of Set 1 | mocuba
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | malmesbury
# Processing Record 0 of Set 2 | magdagachi
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | san quintin
# Processing Record 3 of Set 2 | vilcun
# Processing Record 4 of Set 2 | martinsicuro
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | portland
# Processing Record 10 of Set 2 | pacifica
# Processing Record 11 of Set 2 | raposa
# Processing Record 12 of Set 2 | sumbawa
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 13 of Set 2 | dalinghe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | basoko
# Processing Record 16 of Set 2 | rouvroy
# Processing Record 17 of Set 2 | pavlovka
# Processing Record 18 of Set 2 | belaya gora
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | jumla
# Processing Record 21 of Set 2 | berlevag
# Processing Record 22 of Set 2 | yovon
# Processing Record 23 of Set 2 | umzimvubu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 24 of Set 2 | napkor
# Processing Record 25 of Set 2 | altay
# Processing Record 26 of Set 2 | faya
# Processing Record 27 of Set 2 | hayden
# Processing Record 28 of Set 2 | yumen
# Processing Record 29 of Set 2 | hofn
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | boende
# Processing Record 33 of Set 2 | pouso alegre
# Processing Record 34 of Set 2 | korla
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | tabas
# Processing Record 37 of Set 2 | nova vicosa
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | sorvag
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | ola
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | vrindavan
# Processing Record 45 of Set 2 | seymchan
# Processing Record 46 of Set 2 | sola
# Processing Record 47 of Set 2 | kudahuvadhoo
# Processing Record 48 of Set 2 | bulgan
# Processing Record 49 of Set 2 | disna
# Processing Record 0 of Set 3 | nipawin
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | chermoz
# Processing Record 3 of Set 3 | tual
# Processing Record 4 of Set 3 | isangel
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | sao joao da barra
# Processing Record 7 of Set 3 | san policarpo
# Processing Record 8 of Set 3 | alofi
# Processing Record 9 of Set 3 | mandalgovi
# Processing Record 10 of Set 3 | xuddur
# Processing Record 11 of Set 3 | sao gabriel da cachoeira
# Processing Record 12 of Set 3 | vaini
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | shimoda
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | mullaitivu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 3 | constitucion
# Processing Record 18 of Set 3 | cockburn town
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 21 of Set 3 | koshurnikovo
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | attawapiskat
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 25 of Set 3 | knysna
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | meulaboh
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 30 of Set 3 | seoul
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | clearlake
# Processing Record 33 of Set 3 | tungor
# Processing Record 34 of Set 3 | rawson
# Processing Record 35 of Set 3 | guiratinga
# Processing Record 36 of Set 3 | uusikaupunki
# Processing Record 37 of Set 3 | kenai
# Processing Record 38 of Set 3 | harer
# Processing Record 39 of Set 3 | durango
# Processing Record 40 of Set 3 | severo-kurilsk
# Processing Record 41 of Set 3 | roald
# Processing Record 42 of Set 3 | chapada dos guimaraes
# Processing Record 43 of Set 3 | kunming
# Processing Record 44 of Set 3 | kyshtovka
# Processing Record 45 of Set 3 | kutum
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | ambilobe
# Processing Record 48 of Set 3 | battle creek
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 0 of Set 4 | hermanus
# Processing Record 1 of Set 4 | canaries
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 3 of Set 4 | ostrovnoy
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | atar
# Processing Record 6 of Set 4 | wahiawa
# Processing Record 7 of Set 4 | vreed en hoop
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 4 | ginda
# Processing Record 9 of Set 4 | namibe
# Processing Record 10 of Set 4 | saskylakh
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | tubuala
# Processing Record 13 of Set 4 | raga
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 4 | shingu
# Processing Record 16 of Set 4 | dryden
# Processing Record 17 of Set 4 | santa marta
# Processing Record 18 of Set 4 | maiduguri
# Processing Record 19 of Set 4 | tazovskiy
# Processing Record 20 of Set 4 | muros
# Processing Record 21 of Set 4 | senmonorom
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 22 of Set 4 | comodoro rivadavia
# Processing Record 23 of Set 4 | penzance
# Processing Record 24 of Set 4 | long branch
# Processing Record 25 of Set 4 | huanren
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | viligili
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 4 | aswan
# Processing Record 30 of Set 4 | touros
# Processing Record 31 of Set 4 | flinders
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | taoudenni
# Processing Record 34 of Set 4 | tessalit
# Processing Record 35 of Set 4 | ishigaki
# Processing Record 36 of Set 4 | ciudad bolivar
# Processing Record 37 of Set 4 | lasa
# Processing Record 38 of Set 4 | illoqqortoormiut
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | poway
# Processing Record 42 of Set 4 | pionki
# Processing Record 43 of Set 4 | barra do bugres
# Processing Record 44 of Set 4 | murray bridge
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | junagarh
# Processing Record 47 of Set 4 | lagdo
# Processing Record 48 of Set 4 | asfi
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 0 of Set 5 | laguna
# Processing Record 1 of Set 5 | lagoa
# Processing Record 2 of Set 5 | natal
# Processing Record 3 of Set 5 | lorengau
# Processing Record 4 of Set 5 | saleaula
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 5 | chapaevsk
# Processing Record 6 of Set 5 | fort nelson
# Processing Record 7 of Set 5 | kapuskasing
# Processing Record 8 of Set 5 | clarence town
# Processing Record 9 of Set 5 | enshi
# Processing Record 10 of Set 5 | gidole
# Processing Record 11 of Set 5 | houma
# Processing Record 12 of Set 5 | kindu
# Processing Record 13 of Set 5 | peniche
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | geraldton
# Processing Record 16 of Set 5 | abong mbang
# Processing Record 17 of Set 5 | dikson
# Processing Record 18 of Set 5 | ancud
# Processing Record 19 of Set 5 | kastamonu
# Processing Record 20 of Set 5 | bandarbeyla
# Processing Record 21 of Set 5 | yulara
# Processing Record 22 of Set 5 | sisimiut
# Processing Record 23 of Set 5 | krasnoselkup
# Processing Record 24 of Set 5 | hannibal
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | okhotsk
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | lucapa
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | cidreira
# Processing Record 31 of Set 5 | aberdeen
# Processing Record 32 of Set 5 | port hedland
# Processing Record 33 of Set 5 | mangan
# Processing Record 34 of Set 5 | sangin
# Processing Record 35 of Set 5 | viedma
# Processing Record 36 of Set 5 | caravelas
# Processing Record 37 of Set 5 | saint anthony
# Processing Record 38 of Set 5 | moose factory
# Processing Record 39 of Set 5 | beaumont
# Processing Record 40 of Set 5 | sao filipe
# Processing Record 41 of Set 5 | marathon
# Processing Record 42 of Set 5 | ketchikan
# Processing Record 43 of Set 5 | dwarka
# Processing Record 44 of Set 5 | ye
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 45 of Set 5 | qaqortoq
# Processing Record 46 of Set 5 | sault sainte marie
# Processing Record 47 of Set 5 | broome
# Processing Record 48 of Set 5 | storforshei
# Processing Record 49 of Set 5 | santona
# Processing Record 0 of Set 6 | bethel
# Processing Record 1 of Set 6 | gushikawa
# Processing Record 2 of Set 6 | homer
# Processing Record 3 of Set 6 | vung tau
# Processing Record 4 of Set 6 | ardakan
# Processing Record 5 of Set 6 | chokurdakh
# Processing Record 6 of Set 6 | clyde river
# Processing Record 7 of Set 6 | zhigansk
# Processing Record 8 of Set 6 | puerto del rosario
# Processing Record 9 of Set 6 | santiago del estero
# Processing Record 10 of Set 6 | flin flon
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | thompson
# Processing Record 13 of Set 6 | weyburn
# Processing Record 14 of Set 6 | kurchum
# Processing Record 15 of Set 6 | russell
# Processing Record 16 of Set 6 | cruzeiro do sul
# Processing Record 17 of Set 6 | mahon
# Processing Record 18 of Set 6 | seminole
# Processing Record 19 of Set 6 | mulege
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | larap
# Processing Record 22 of Set 6 | tunduru
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 23 of Set 6 | salalah
# Processing Record 24 of Set 6 | krapina
# Processing Record 25 of Set 6 | ahuimanu
# Processing Record 26 of Set 6 | gobabis
# Processing Record 27 of Set 6 | kumluca
# Processing Record 28 of Set 6 | sao miguel do araguaia
# Processing Record 29 of Set 6 | watertown
# Processing Record 30 of Set 6 | canton
# Processing Record 31 of Set 6 | pangkalanbuun
# Processing Record 32 of Set 6 | totma
# Processing Record 33 of Set 6 | burica
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 34 of Set 6 | snihurivka
# Processing Record 35 of Set 6 | saint-medard-en-jalles
# Processing Record 36 of Set 6 | byron bay
# Processing Record 37 of Set 6 | luanda
# Processing Record 38 of Set 6 | taganak
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 6 | kavieng
# Processing Record 41 of Set 6 | huejuquilla el alto
# Processing Record 42 of Set 6 | te anau
# Processing Record 43 of Set 6 | daltenganj
# Processing Record 44 of Set 6 | urucui
# Processing Record 45 of Set 6 | buraydah
# Processing Record 46 of Set 6 | fairbanks
# Processing Record 47 of Set 6 | mackay
# Processing Record 48 of Set 6 | parkent
# Processing Record 49 of Set 6 | sao felix do xingu
# Processing Record 0 of Set 7 | mayumba
# Processing Record 1 of Set 7 | tasiilaq
# Processing Record 2 of Set 7 | nikolskoye
# Processing Record 3 of Set 7 | pareora
# Processing Record 4 of Set 7 | jalu
# Processing Record 5 of Set 7 | najran
# Processing Record 6 of Set 7 | muroto
# Processing Record 7 of Set 7 | bambous virieux
# Processing Record 8 of Set 7 | tucurui
# Processing Record 9 of Set 7 | iqaluit
# Processing Record 10 of Set 7 | wanning
# Processing Record 11 of Set 7 | hai phong
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 12 of Set 7 | nizhniy tsasuchey
# Processing Record 13 of Set 7 | inhambane
# Processing Record 14 of Set 7 | fuxin
# Processing Record 15 of Set 7 | meadow lake
# Processing Record 16 of Set 7 | marcona
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 7 | toliary
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 18 of Set 7 | shizunai
# Processing Record 19 of Set 7 | ziniare
# Processing Record 20 of Set 7 | pskov
# Processing Record 21 of Set 7 | half moon bay
# Processing Record 22 of Set 7 | pacific grove
# Processing Record 23 of Set 7 | mahebourg
# Processing Record 24 of Set 7 | carutapera
# Processing Record 25 of Set 7 | akureyri
# Processing Record 26 of Set 7 | samarai
# Processing Record 27 of Set 7 | amapa
# Processing Record 28 of Set 7 | charters towers
# Processing Record 29 of Set 7 | longyearbyen
# Processing Record 30 of Set 7 | amambai
# Processing Record 31 of Set 7 | anadyr
# Processing Record 32 of Set 7 | nakamura
# Processing Record 33 of Set 7 | leh
# Processing Record 34 of Set 7 | kazachinskoye
# Processing Record 35 of Set 7 | oarai
# Processing Record 36 of Set 7 | novikovo
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | marang
# Processing Record 39 of Set 7 | methoni
# Processing Record 40 of Set 7 | grants
# Processing Record 41 of Set 7 | goderich
# Processing Record 42 of Set 7 | grindavik
# Processing Record 43 of Set 7 | elizabeth city
# Processing Record 44 of Set 7 | kismayo
# Processing Record 45 of Set 7 | westport
# Processing Record 46 of Set 7 | maku
# Processing Record 47 of Set 7 | newport
# Processing Record 48 of Set 7 | alihe
# Processing Record 49 of Set 7 | walvis bay
# Processing Record 0 of Set 8 | haapsalu
# Processing Record 1 of Set 8 | mergui
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 2 of Set 8 | nemuro
# Processing Record 3 of Set 8 | san patricio
# Processing Record 4 of Set 8 | berdigestyakh
# Processing Record 5 of Set 8 | coron
# Processing Record 6 of Set 8 | hamilton
# Processing Record 7 of Set 8 | deputatskiy
# Processing Record 8 of Set 8 | inhuma
# Processing Record 9 of Set 8 | port elizabeth
# Processing Record 10 of Set 8 | batemans bay
# Processing Record 11 of Set 8 | bucerias
# Processing Record 12 of Set 8 | mount isa
# Processing Record 13 of Set 8 | itaparica
# Processing Record 14 of Set 8 | handwara
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 8 | samalaeulu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 16 of Set 8 | tavda
# Processing Record 17 of Set 8 | thinadhoo
# Processing Record 18 of Set 8 | dorado
# Processing Record 19 of Set 8 | binga
# Processing Record 20 of Set 8 | torbay
# Processing Record 21 of Set 8 | vao
# Processing Record 22 of Set 8 | grand gaube
# Processing Record 23 of Set 8 | aleksandrov gay
# Processing Record 24 of Set 8 | hastings
# Processing Record 25 of Set 8 | baykit
# Processing Record 26 of Set 8 | bud
# Processing Record 27 of Set 8 | kazalinsk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 28 of Set 8 | selishche
# Processing Record 29 of Set 8 | roma
# Processing Record 30 of Set 8 | zabol
# Processing Record 31 of Set 8 | yar-sale
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 33 of Set 8 | archidona
# Processing Record 34 of Set 8 | vila franca do campo
# Processing Record 35 of Set 8 | hasaki
# Processing Record 36 of Set 8 | airai
# Processing Record 37 of Set 8 | thanh hoa
# Processing Record 38 of Set 8 | kavaratti
# Processing Record 39 of Set 8 | palasa
# Processing Record 40 of Set 8 | limon
# Processing Record 41 of Set 8 | bonthe
# Processing Record 42 of Set 8 | ylojarvi
# Processing Record 43 of Set 8 | diffa
# Processing Record 44 of Set 8 | la uribe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 45 of Set 8 | guayabetal
# Processing Record 46 of Set 8 | beloha
# Processing Record 47 of Set 8 | bermejo
# Processing Record 48 of Set 8 | dumai
# Processing Record 49 of Set 8 | howard springs
# Processing Record 0 of Set 9 | asayita
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 1 of Set 9 | faanui
# Processing Record 2 of Set 9 | souillac
# Processing Record 3 of Set 9 | inverell
# Processing Record 4 of Set 9 | mahibadhoo
# Processing Record 5 of Set 9 | tura
# Processing Record 6 of Set 9 | derzhavinsk
# Processing Record 7 of Set 9 | huarmey
# Processing Record 8 of Set 9 | dingle
# Processing Record 9 of Set 9 | tanglad
# Processing Record 10 of Set 9 | jabiru
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 11 of Set 9 | trincomalee
# Processing Record 12 of Set 9 | vila velha
# Processing Record 13 of Set 9 | antofagasta
# Processing Record 14 of Set 9 | dicabisagan
# Processing Record 15 of Set 9 | arauco
# Processing Record 16 of Set 9 | kautokeino
# Processing Record 17 of Set 9 | ozernovskiy
# Processing Record 18 of Set 9 | santa cruz verapaz
# Processing Record 19 of Set 9 | dodge city
# Processing Record 20 of Set 9 | koulikoro
# Processing Record 21 of Set 9 | elin pelin
# Processing Record 22 of Set 9 | odienne
# Processing Record 23 of Set 9 | cururupu
# Processing Record 24 of Set 9 | itamaraju
# Processing Record 25 of Set 9 | auki
# Processing Record 26 of Set 9 | srandakan
# Processing Record 27 of Set 9 | carlos antonio lopez
# Processing Record 28 of Set 9 | shieli
# Processing Record 29 of Set 9 | sorland
# Processing Record 30 of Set 9 | lengshuijiang
# Processing Record 31 of Set 9 | stralsund
# Processing Record 32 of Set 9 | tocopilla
# Processing Record 33 of Set 9 | tumannyy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 34 of Set 9 | ushtobe
# Processing Record 35 of Set 9 | khasan
# Processing Record 36 of Set 9 | fare
# Processing Record 37 of Set 9 | erzin
# Processing Record 38 of Set 9 | upernavik
# Processing Record 39 of Set 9 | ocher
# Processing Record 40 of Set 9 | bonavista
# Processing Record 41 of Set 9 | hit
# Processing Record 42 of Set 9 | dong hoi
# Processing Record 43 of Set 9 | whitehorse
# Processing Record 44 of Set 9 | padilla
# Processing Record 45 of Set 9 | sinnamary
# Processing Record 46 of Set 9 | aquiraz
# Processing Record 47 of Set 9 | merritt island
# Processing Record 48 of Set 9 | kilrush
# Processing Record 49 of Set 9 | dukat
# Processing Record 0 of Set 10 | sao jose da coroa grande
# Processing Record 1 of Set 10 | manhattan
# Processing Record 2 of Set 10 | suez
# Processing Record 3 of Set 10 | muravlenko
# Processing Record 4 of Set 10 | miragoane
# Processing Record 5 of Set 10 | pitimbu
# Processing Record 6 of Set 10 | marienburg
# Processing Record 7 of Set 10 | phan rang
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 10 | sidi qasim
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 9 of Set 10 | abu samrah
# Processing Record 10 of Set 10 | umea
# Processing Record 11 of Set 10 | todos santos
# Processing Record 12 of Set 10 | labytnangi
# Processing Record 13 of Set 10 | leshukonskoye
# Processing Record 14 of Set 10 | barranca
# Processing Record 15 of Set 10 | sungaipenuh
# Processing Record 16 of Set 10 | krasnoye
# Processing Record 17 of Set 10 | turtas
# Processing Record 18 of Set 10 | marsabit
# Processing Record 19 of Set 10 | puerto narino
# Processing Record 20 of Set 10 | port-gentil
# Processing Record 21 of Set 10 | general roca
# Processing Record 22 of Set 10 | beringovskiy
# Processing Record 23 of Set 10 | bowen
# Processing Record 24 of Set 10 | port blair
# Processing Record 25 of Set 10 | hay river
# Processing Record 26 of Set 10 | barawe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 27 of Set 10 | babanusah
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 28 of Set 10 | mandal
# Processing Record 29 of Set 10 | manaure
# Processing Record 30 of Set 10 | buenos aires
# Processing Record 31 of Set 10 | chimoio
# Processing Record 32 of Set 10 | betare oya
# Processing Record 33 of Set 10 | plettenberg bay
# Processing Record 34 of Set 10 | hovd
# Processing Record 35 of Set 10 | hadejia
# Processing Record 36 of Set 10 | sioux lookout
# Processing Record 37 of Set 10 | estacion coahuila
# Processing Record 38 of Set 10 | vuktyl
# Processing Record 39 of Set 10 | bara
# Processing Record 40 of Set 10 | kiunga
# Processing Record 41 of Set 10 | lalomanu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 10 | eyl
# Processing Record 43 of Set 10 | norman wells
# Processing Record 44 of Set 10 | haines junction
# Processing Record 45 of Set 10 | mahadday weyne
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 46 of Set 10 | burnie
# Processing Record 47 of Set 10 | luwuk
# Processing Record 48 of Set 10 | svetlogorsk
# Processing Record 49 of Set 10 | stephenville
# Processing Record 0 of Set 11 | higueron
# Processing Record 1 of Set 11 | ghanzi
# Processing Record 2 of Set 11 | chakia
# Processing Record 3 of Set 11 | vestmannaeyjar
# Processing Record 4 of Set 11 | lata
# Processing Record 5 of Set 11 | lubango
# Processing Record 6 of Set 11 | marsh harbour
# Processing Record 7 of Set 11 | katsuura
# Processing Record 8 of Set 11 | vaitape
# Processing Record 9 of Set 11 | orotukan
# Processing Record 10 of Set 11 | umm lajj
# Processing Record 11 of Set 11 | libertador general san martin
# Processing Record 12 of Set 11 | zyryanka
# Processing Record 13 of Set 11 | sawakin
# Processing Record 14 of Set 11 | maryville
# Processing Record 15 of Set 11 | kommunisticheskiy
# Processing Record 16 of Set 11 | conakry
# Processing Record 17 of Set 11 | south venice
# Processing Record 18 of Set 11 | santa rosa
# Processing Record 19 of Set 11 | asau
# Processing Record 20 of Set 11 | agadez
# Processing Record 21 of Set 11 | phan thiet
# Processing Record 22 of Set 11 | kruisfontein
# Processing Record 23 of Set 11 | taixing
# Processing Record 24 of Set 11 | urucara
# Processing Record 25 of Set 11 | cabo san lucas
# Processing Record 26 of Set 11 | altoona
# Processing Record 27 of Set 11 | shkotovo-22
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 28 of Set 11 | manggar
# Processing Record 29 of Set 11 | hami
# Processing Record 30 of Set 11 | lufilufi
# Processing Record 31 of Set 11 | vallenar
# Processing Record 32 of Set 11 | adrar
# Processing Record 33 of Set 11 | hanyang
# Processing Record 34 of Set 11 | maningrida
# Processing Record 35 of Set 11 | osmena
# Processing Record 36 of Set 11 | shenzhen
# Processing Record 37 of Set 11 | tiksi
# Processing Record 38 of Set 11 | tuatapere
# Processing Record 39 of Set 11 | dawlatabad
# Processing Record 40 of Set 11 | sterlitamak
# Processing Record 41 of Set 11 | ishikawa
# Processing Record 42 of Set 11 | upata
# Processing Record 43 of Set 11 | mago
# Processing Record 44 of Set 11 | dulovo
# Processing Record 45 of Set 11 | calama
# Processing Record 46 of Set 11 | vanimo
# Processing Record 47 of Set 11 | aklavik
# Processing Record 48 of Set 11 | moerai
# Processing Record 49 of Set 11 | maldonado
# Processing Record 0 of Set 12 | worland
# Processing Record 1 of Set 12 | tianpeng
# Processing Record 2 of Set 12 | sarangani
# Processing Record 3 of Set 12 | colares
# Processing Record 4 of Set 12 | nileshwar
# Processing Record 5 of Set 12 | seidu
# Processing Record 6 of Set 12 | hanzhong
# Processing Record 7 of Set 12 | do rud
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 12 | nuuk
# Processing Record 9 of Set 12 | koping
# Processing Record 10 of Set 12 | omsukchan
# Processing Record 11 of Set 12 | piacabucu
# Processing Record 12 of Set 12 | itacoatiara
# Processing Record 13 of Set 12 | kidal
# Processing Record 14 of Set 12 | komsomolskiy
# Processing Record 15 of Set 12 | cozumel
# Processing Record 16 of Set 12 | alekseyevskoye
# Processing Record 17 of Set 12 | paamiut
# Processing Record 18 of Set 12 | awjilah
# Processing Record 19 of Set 12 | danville
# Processing Record 20 of Set 12 | sept-iles
# Processing Record 21 of Set 12 | fukue
# Processing Record 22 of Set 12 | fort saint james
# Processing Record 23 of Set 12 | oum hadjer
# Processing Record 24 of Set 12 | magistralnyy
# Processing Record 25 of Set 12 | benghazi
# Processing Record 26 of Set 12 | buritis
# Processing Record 27 of Set 12 | husavik
# Processing Record 28 of Set 12 | hualmay
# Processing Record 29 of Set 12 | tommot
# Processing Record 30 of Set 12 | nisia floresta
# Processing Record 31 of Set 12 | tarakan
# Processing Record 32 of Set 12 | tezu
# Processing Record 33 of Set 12 | orlik
# Processing Record 34 of Set 12 | cambridge
# Processing Record 35 of Set 12 | vila
# Processing Record 36 of Set 12 | palamuse
# Processing Record 37 of Set 12 | kattivakkam
# Processing Record 38 of Set 12 | angra
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 39 of Set 12 | coihaique
# Processing Record 40 of Set 12 | sampit
# Processing Record 41 of Set 12 | ballina
# Processing Record 42 of Set 12 | pirai do sul
# Processing Record 43 of Set 12 | haibowan
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 44 of Set 12 | willmar
# Processing Record 45 of Set 12 | kedrovyy
# Processing Record 46 of Set 12 | dubti
# Processing Record 47 of Set 12 | brandon
# Processing Record 48 of Set 12 | staryy nadym
# Processing Record 49 of Set 12 | rondonopolis
# Processing Record 0 of Set 13 | berbera
# Processing Record 1 of Set 13 | mount pleasant
# Processing Record 2 of Set 13 | ornskoldsvik
# Processing Record 3 of Set 13 | marfino
# Processing Record 4 of Set 13 | patos
# Processing Record 5 of Set 13 | kota belud
# Processing Record 6 of Set 13 | huilong

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)


# Extract relevant fields from the data frame
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Windspeed"]

city_data_df.to_csv(output_data_file, index_label="City_ID")
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Windspeed     561
# Country       561
# Date          561
# dtype: int64

# %%
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    punta arenas -53.1500  -70.9167     44.71        87          40
# 1  ribeira grande  38.5167  -28.7000     75.60        73          75
# 2       jamestown  42.0970  -79.2353     73.02        63         100
# 3     port alfred -33.5906   26.8910     55.56        71           0
# 4        bengkulu  -3.8004  102.2655     72.79        90         100
#
#    Windspeed Country        Date
# 0      21.85      CL  1661114039
# 1       1.14      PT  1661113945
# 2      13.80      US  1661114157
# 3       4.41      ZA  1661114157
# 4       4.79      ID  1661114158

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
city_with_humidity_100 = city_data_df['Humidity']
for x in city_with_humidity_100:
    if x > 100:
        print(city_data_df['City'])

#there is no city have humidity over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, max_temps, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig1.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build scatter plot for latitude vs. Humidity
plt.scatter(lats, humidity,edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig2.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build scatter plot for latitude vs. Cloudiness
plt.scatter(lats, cloudiness, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude Vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig3.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. Windspeed
plt.scatter(lats,
            wind_speed,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

plt.title("City Latitude Vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Windspeed mph")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig4.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# # OPTIONAL: Create a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (10,60))
# Out:
# The r-squared is: -0.6880789451667095

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,55))
# Out:
# The r-squared is: 0.8021212341400126

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (50,40))
# Out:
# The r-squared is: 0.021565004951313874

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-55,60))
# Out:
# The r-squared is: -0.08508901340289896

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (50,50))
# Out:
# The r-squared is: -0.008650172328966305

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.17803303615047997

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (40,25))
# Out:
# The r-squared is: -0.11507313782715389

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (-25,23))
# Out:
# The r-squared is: -0.06633625893749963
